# %%
import os
from pathlib import Path
from azureml.core import Workspace


def _load_env_file(env_path: Path) -> None:
    if not env_path.exists():
        return
    for raw_line in env_path.read_text(encoding="utf-8").splitlines():
        line = raw_line.strip()
        if not line or line.startswith("#") or "=" not in line:
            continue
        key, value = line.split("=", 1)
        if key and key not in os.environ:
            os.environ[key] = value


# Load .env from parent directory
env_path = Path("../../.env").resolve()
_load_env_file(env_path)

# Connect to workspace using secrets from .env
ws = Workspace(
    subscription_id=os.environ["AZUREML_SUBSCRIPTION_ID"],
    resource_group=os.environ["AZUREML_RESOURCE_GROUP"],
    workspace_name=os.environ["AZUREML_WORKSPACE_NAME"]
)

print(f"Connected to workspace: {ws.name}")
print(f"Location: {ws.location}, Resource Group: {ws.resource_group}")
# Out:
# Connected to workspace: data-factory
# Location: northeurope, Resource Group: RG_JIT02

# %%
from azure.ai.ml import command, Input, Output

train_component = command(
    name="train-model-local",
    display_name="Train Model (Local)",
    inputs={"training_data": Input(type="uri_file")},
    outputs={"model_output": Output(type="uri_folder")},
    code="./src",  # folder with train.py
    command="python train.py --data ${{inputs.training_data}} --output ${{outputs.model_output}}",
    environment="AzureML-sklearn-1.0-ubuntu20.04-py38-cpu",
    compute="local"   # ✅ run locally
)

# %%
from azure.ai.ml.dsl import pipeline

@pipeline()
def local_pipeline(training_data):
    trained_model = train_component(training_data=training_data)
    return {"model_output": trained_model.outputs.model_output}

# %%
pip install azureml.pipeline
# Out:
# Requirement already satisfied: azureml.pipeline in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (1.61.0)
# Requirement already satisfied: azureml-pipeline-core~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml.pipeline) (1.61.0)
# Requirement already satisfied: azureml-pipeline-steps~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml.pipeline) (1.61.0)
# Requirement already satisfied: azureml-core~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.61.0.post1)
# Requirement already satisfied: pytz in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2025.2)
# Requirement already satisfied: backports.tempfile in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.0)
# Requirement already satisfied: pathspec<1.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2.32.5)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.34.0)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.3.1)
# Requirement already satisfied: knack<0.13.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.12.0)
# Requirement already satisfied: azure-core<2.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.38.1)
# Requirement already satisfied: pkginfo in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.12.1.2)
# Requirement already satisfied: argcomplete<4 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (3.6.3)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (10.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (3.5.1)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (24.0.0)
# Requirement already satisfied: azure-mgmt-containerregistry<15,>=8.2.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (14.0.0)
# Requirement already satisfied: azure-mgmt-storage<=24.0.0,>=16.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (24.0.0)
# Requirement already satisfied: azure-mgmt-keyvault<12.0.0,>=0.40.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (11.0.0)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (4.0.0)
# Requirement already satisfied: azure-mgmt-network<=30.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (30.0.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.61.2)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.1.28)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.7.1)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.6.4.post1)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2.6.3)
# Requirement already satisfied: packaging<26.0,>=20.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2.9.0.post0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.5.1)
# Requirement already satisfied: SecretStorage<4.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (3.3.3)
# Requirement already satisfied: jsonpickle<5.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (4.1.1)
# Requirement already satisfied: contextlib2<22.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (21.6.0)
# Requirement already satisfied: docker<8.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (7.1.0)
# Requirement already satisfied: PyJWT<3.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2.11.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.2.7)
# Requirement already satisfied: pyopenssl<26.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (25.3.0)
# Requirement already satisfied: jmespath<2.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.1.0)
# Requirement already satisfied: cryptography>=1.1.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from adal<=1.2.7,>=1.2.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (46.0.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azure-core<2.0.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (4.15.0)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.7.2)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.6.0)
# Requirement already satisfied: azureml-train-core~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-pipeline-steps~=1.61.0->azureml.pipeline) (1.61.0)
# Requirement already satisfied: azureml-train-automl-client~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-pipeline-steps~=1.61.0->azureml.pipeline) (1.61.0.post1)
# Requirement already satisfied: azureml-automl-core~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (1.61.0.post1)
# Requirement already satisfied: azureml-dataset-runtime~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (1.61.0)
# Requirement already satisfied: azureml-telemetry~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (1.61.0)
# Requirement already satisfied: importlib-metadata<=8.2.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-automl-core~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (8.2.0)
# Requirement already satisfied: importlib-resources<=6.4.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-automl-core~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (6.4.0)
# Requirement already satisfied: azureml-dataprep<5.5.0a,>=5.1.0a in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (5.4.3)
# Requirement already satisfied: pyarrow<21.0.0,>=0.17.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (20.0.0)
# Requirement already satisfied: numpy!=1.19.4,<2.3.3 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (2.0.2)
# Requirement already satisfied: azureml-dataprep-native<43.0.0,>=42.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (42.1.0)
# Requirement already satisfied: azureml-dataprep-rslex~=2.25.1 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (2.25.3)
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (2.2.1)
# Requirement already satisfied: azure-identity<=1.17.0,>=1.16.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (1.17.0)
# Requirement already satisfied: jsonschema in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (4.25.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (6.0.3)
# Requirement already satisfied: pip>=25.3 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (26.0.1)
# Requirement already satisfied: applicationinsights in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-telemetry~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (0.11.10)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.61.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from azureml-train-core~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (1.61.0)
# Requirement already satisfied: pywin32>=304 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from docker<8.0.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (311)
# Requirement already satisfied: pyreadline3 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from humanfriendly<11.0,>=4.7->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (3.5.4)
# Requirement already satisfied: zipp>=0.5 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from importlib-metadata<=8.2.0->azureml-automl-core~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (3.23.0)
# Requirement already satisfied: pygments in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from knack<0.13.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2.19.2)
# Requirement already satisfied: tabulate in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from knack<0.13.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.9.0)
# Requirement already satisfied: cffi>=2.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2026.1.4)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2.0.0)
# Requirement already satisfied: six in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from msrestazure<=0.7,>=0.4.33->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.17.0)
# Requirement already satisfied: pyasn1>=0.1.1 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.6.2)
# Requirement already satisfied: bcrypt>=3.2 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (5.0.0)
# Requirement already satisfied: pynacl>=1.5 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (3.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from SecretStorage<4.0.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (0.9.0)
# Requirement already satisfied: pycparser in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (2.23)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (3.3.1)
# Requirement already satisfied: backports.weakref in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from backports.tempfile->azureml-core~=1.61.0->azureml-pipeline-core~=1.61.0->azureml.pipeline) (1.0.post1)
# Requirement already satisfied: attrs>=22.2.0 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from jsonschema->azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from jsonschema->azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from jsonschema->azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\aiinstitute\data_factory\2_amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages (from jsonschema->azureml-dataprep<5.5.0a,>=5.1.0a->azureml-dataset-runtime~=1.61.0->azureml-train-automl-client~=1.61.0->azureml-pipeline-steps~=1.61.0->azureml.pipeline) (0.27.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a simple pipeline using the workspace from cell 1
from azureml.pipeline.core import Pipeline, PipelineData
from azureml.pipeline.steps import PythonScriptStep
from azureml.core import Environment, ScriptRunConfig, Experiment
from pathlib import Path

# Get the correct path to the root directory
notebook_dir = Path.cwd()
root_dir = notebook_dir.parent.parent

# Load the environment from environment.yml
env_file = root_dir / "environment.yml"
env = Environment.from_conda_specification(name="ml-env", file_path=str(env_file))

# Define pipeline outputs
prepared_data = PipelineData("prepared_data", datastore=ws.get_default_datastore())
model_output = PipelineData("model_output", datastore=ws.get_default_datastore())

# Create a simple prep step
prep_step = PythonScriptStep(
    name="Prep Data",
    script_name="prep.py",
    arguments=["--output", prepared_data],
    outputs=[prepared_data],
    compute_target="pipe-action",
    source_directory=str(root_dir),
    runconfig=ScriptRunConfig(source_directory=str(root_dir), environment=env)
)

# Build and submit the pipeline
pipeline = Pipeline(workspace=ws, steps=[prep_step])
exp = Experiment(workspace=ws, name="test-pipeline")
run = exp.submit(pipeline)

print(f"Pipeline submitted. Run ID: {run.id}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 13
#      11 # Load the environment from environment.yml
#      12 env_file = root_dir / "environment.yml"
# ---> 13 env = Environment.from_conda_specification(name="ml-env", file_path=str(env_file))
#      15 # Define pipeline outputs
#      16 prepared_data = PipelineData("prepared_data", datastore=ws.get_default_datastore())
#
# File d:\aiinstitute\data_factory\2_Amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages\azureml\core\environment.py:1302, in Environment.from_conda_specification(name, file_path)
#    1287 @staticmethod
#    1288 def from_conda_specification(name, file_path):
#    1289     """Create environment object from an environment specification YAML file.
#    1290
#    1291     To get an environment specification YAML file, see `Managing environments
#    (...)
#    1300     :rtype: azureml.core.environment.Environment
#    1301     """  # noqa: E501
# -> 1302     conda_dependencies = CondaDependencies(conda_dependencies_file_path=file_path)
#    1303     if not conda_dependencies._python_version:
#    1304         module_logger.warning('No Python version provided, defaulting to "{}"'.format(PYTHON_DEFAULT_VERSION))
#
# File d:\aiinstitute\data_factory\2_Amsterdam\test_pipeline\azure_ml_with_github_action\.venv\lib\site-packages\azureml\core\conda_dependencies.py:131, in CondaDependencies.__init__(self, conda_dependencies_file_path, _underlying_structure)
#     129     conda_dependencies_file_path = os.path.normpath(conda_dependencies_file_path)
#     130     # CodeQL [SM01305] untrusted data is validated before being used in the path
# --> 131     with open(conda_dependencies_file_path, "r") as input:
#     132         self._conda_dependencies = ruamelyaml.round_trip_load(input)
#     133 elif _underlying_structure is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:\\aiinstitute\\data_factory\\2_Amsterdam\\test_pipeline\\environment.yml'
